# %% [markdown]
# ## [How to convert trained Keras model to a single TensorFlow .pb file and make prediction](https://www.dlology.com/blog/how-to-convert-trained-keras-model-to-tensorflow-and-make-prediction/)
#
#
# - Train Keras model
# - Keras to single TensorFlow .pb file
# - Load .pb file with TensorFlow and make prediction.
# - (Optional) Visualize the graph in Jupyter notebook.

# %% [markdown]
# ## Create, compile and train model

# %%
from __future__ import print_function
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K

batch_size = 128
num_classes = 10
epochs = 5

# input image dimensions
img_rows, img_cols = 28, 28

# the data, split between train and test sets
(x_train, y_train), (x_test, y_test) = mnist.load_data()

if K.image_data_format() == 'channels_first':
    x_train = x_train.reshape(x_train.shape[0], 1, img_rows, img_cols)
    x_test = x_test.reshape(x_test.shape[0], 1, img_rows, img_cols)
    input_shape = (1, img_rows, img_cols)
else:
    x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, 1)
    x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, 1)
    input_shape = (img_rows, img_cols, 1)

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3),
                 activation='relu',
                 input_shape=input_shape))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.Adadelta(),
              metrics=['accuracy'])

model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(x_test, y_test))
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Using TensorFlow backend.
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 9s 149us/step - loss: 0.2691 - acc: 0.9170 - val_loss: 0.0540 - val_acc: 0.9830
# Epoch 2/5
# 60000/60000 [==============================] - 6s 92us/step - loss: 0.0900 - acc: 0.9735 - val_loss: 0.0388 - val_acc: 0.9870
# Epoch 3/5
# 60000/60000 [==============================] - 6s 92us/step - loss: 0.0670 - acc: 0.9803 - val_loss: 0.0354 - val_acc: 0.9881
# Epoch 4/5
# 60000/60000 [==============================] - 5s 92us/step - loss: 0.0526 - acc: 0.9841 - val_loss: 0.0306 - val_acc: 0.9910
# Epoch 5/5
# 60000/60000 [==============================] - 5s 91us/step - loss: 0.0469 - acc: 0.9860 - val_loss: 0.0328 - val_acc: 0.9891
# Test loss: 0.03276554842220285
# Test accuracy: 0.9891

# %% [markdown]
# ### Save Keras model to a file (optional)

# %%
import os
os.makedirs('./model', exist_ok=True)
model.save('./model/keras_model.h5')

# %% [markdown]
# ### Load Keras model from a file (optional)

# %% [markdown]
# In case you ran into the **incompatible with expected resource** issue with a model containing **BatchNormization** layers such as DenseNet, make sure to set the learning phase to 0 before loading the Keras model in a new session.
# The error message looks like this when you call `tf.import_graph_def(graph_def)` later on during restoring.
# ```
# Conv_1/cond/ReadVariableOp/Switch was passed float from Conv_1/gamma:0 incompatible with expected resource
# ```

# %%
from keras import backend as K
# This line must be executed before loading Keras model.
K.set_learning_phase(0)

# %%
from keras.models import load_model
model = load_model('./model/keras_model.h5')
# Out:
# Using TensorFlow backend.

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 26, 26, 32)        320
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 24, 24, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 12, 12, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 12, 12, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 9216)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               1179776
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 1,199,882
# Trainable params: 1,199,882
# Non-trainable params: 0
# _________________________________________________________________

# %%
from show_graph import show_graph
from keras import backend as K
import tensorflow as tf
sess = K.get_session()
graph_def = sess.graph.as_graph_def()
# graph_def
show_graph(graph_def)
# Out:
#         <iframe seamless style="width:1200px;height:620px;border:0" srcdoc="
#         <script>
#           function load() {
#             document.getElementById(&quot;graph0.7046161635089256&quot;).pbtxt = 'node {\n  name: &quot;conv2d_1_input&quot;\n  op: &quot;Placeholder&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n        dim {\n          size: -1\n        }\n        dim {\n          size: 28\n        }\n        dim {\n          size: 28\n        }\n        dim {\n          size: 1\n        }\n      }\n    }\n  }\n}\nnode {\n  name: &quot;conv2d_1/random_uniform/shape&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_INT32\n        tensor_shape {\n          dim {\n            size: 4\n          }\n        }\n        tensor_content: &quot;\\003\\000\\000\\000\\003\\000\\000\\000\\001\\000\\000\\000 \\000\\000\\000&quot;\n      }\n    }\n  }\n}\nnode {\n  name: &quot;conv2d_1/random_uniform/min&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_FLOAT\n        tensor_shape {\n        }\n        float_val: -0.14213381707668304\n      }\n    }\n  }\n}\nnode {\n  name: &quot;conv2d_1/random_uniform/max&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_FLOAT\n        tensor_shape {\n        }\n        float_val: 0.14213381707668304\n      }\n    }\n  }\n}\nnode {\n  name: &quot;conv2d_1/random_uniform/RandomUniform&quot;\n  op: &quot;RandomUniform&quot;\n  input: &quot;conv2d_1/random_uniform/shape&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_INT32\n    }\n  }\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;seed&quot;\n    value {\n      i: 87654321\n    }\n  }\n  attr {\n    key: &quot;seed2&quot;\n    value {\n      i: 6828613\n    }\n  }\n}\nnode {\n  name: &quot;conv2d_1/random_uniform/sub&quot;\n  op: &quot;Sub&quot;\n  input: &quot;conv2d_1/random_uniform/max&quot;\n  input: &quot;conv2d_1/random_uniform/min&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n}\nnode {\n  name: &quot;conv2d_1/random_uniform/mul&quot;\n  op: &quot;Mul&quot;\n  input: &quot;conv2d_1/random_uniform/RandomUniform&quot;\n  input: &quot;conv2d_1/random_uniform/sub&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n}\nnode {\n  name: &quot;conv2d_1/random_uniform&quot;\n  op: &quot;Add&quot;\n  input: &quot;conv2d_1/random_uniform/mul&quot;\n  input: &quot;conv2d_1/random_uniform/min&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n}\nnode {\n  name: &quot;conv2d_1/kernel&quot;\n  op: &quot;VariableV2&quot;\n  attr {\n    key: &quot;container&quot;\n    value {\n      s: &quot;&quot;\n    }\n  }\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n        dim {\n          size: 3\n        }\n        dim {\n          size: 3\n        }\n        dim {\n          size: 1\n        }\n        dim {\n          size: 32\n        }\n      }\n    }\n  }\n  attr {\n    key: &quot;shared_name&quot;\n    value {\n      s: &quot;&quot;\n    }\n  }\n}\nnode {\n  name: &quot;conv2d_1/kernel/Assign&quot;\n  op: &quot;Assign&quot;\n  input: &quot;conv2d_1/kernel&quot;\n  input: &quot;conv2d_1/random_uniform&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;_class&quot;\n    value {\n      list {\n        s: &quot;loc:@conv2d_1/kernel&quot;\n      }\n    }\n  }\n  attr {\n     ...

# %% [markdown]
# ### Check the input and output name
# We will refer to them by name during TensorFlow inference.

# %%
print(model.outputs)
# Out:
# [<tf.Tensor 'dense_2/Softmax:0' shape=(?, 10) dtype=float32>]

# %%
print(model.inputs)
# Out:
# [<tf.Tensor 'conv2d_1_input:0' shape=(?, 28, 28, 1) dtype=float32>]

# %%
def freeze_session(session, keep_var_names=None, output_names=None, clear_devices=True):
    """
    Freezes the state of a session into a pruned computation graph.

    Creates a new computation graph where variable nodes are replaced by
    constants taking their current value in the session. The new graph will be
    pruned so subgraphs that are not necessary to compute the requested
    outputs are removed.
    @param session The TensorFlow session to be frozen.
    @param keep_var_names A list of variable names that should not be frozen,
                          or None to freeze all the variables in the graph.
    @param output_names Names of the relevant graph outputs.
    @param clear_devices Remove the device directives from the graph for better portability.
    @return The frozen graph definition.
    """
    from tensorflow.python.framework.graph_util import convert_variables_to_constants
    graph = session.graph
    with graph.as_default():
        freeze_var_names = list(set(v.op.name for v in tf.global_variables()).difference(keep_var_names or []))
        output_names = output_names or []
        output_names += [v.op.name for v in tf.global_variables()]
        # Graph -> GraphDef ProtoBuf
        input_graph_def = graph.as_graph_def()
        if clear_devices:
            for node in input_graph_def.node:
                node.device = ""
        frozen_graph = convert_variables_to_constants(session, input_graph_def,
                                                      output_names, freeze_var_names)
        return frozen_graph

# %%
from keras import backend as K
import tensorflow as tf

frozen_graph = freeze_session(K.get_session(),
                              output_names=[out.op.name for out in model.outputs])
# Out:
# INFO:tensorflow:Froze 27 variables.
# INFO:tensorflow:Converted 27 variables to const ops.

# %% [markdown]
# Save `GraphDef` ProtoBuf as a binary file.

# %%
tf.train.write_graph(frozen_graph, "model", "tf_model.pb", as_text=False)
# Out:
# 'model\\tf_model.pb'

# %% [markdown]
# ## Load the pb file and inference
# **Restart the Kernel first to clear previous training session.**

# %%
import tensorflow as tf
import os
import sys
from tensorflow.python.platform import gfile

# %%
sess=tf.InteractiveSession()

# %%
f = gfile.FastGFile("./model/tf_model.pb", 'rb')
graph_def = tf.GraphDef()
# Parses a serialized binary message into the current message.
graph_def.ParseFromString(f.read())
f.close()

# %%
sess.graph.as_default()
# Import a serialized TensorFlow `GraphDef` protocol buffer
# and place into the current default `Graph`.
tf.import_graph_def(graph_def)

# %% [markdown]
# ### Locate the output Tensor by name

# %%
softmax_tensor = sess.graph.get_tensor_by_name('import/dense_2/Softmax:0')

# %% [markdown]
# ### Prepare datasets for inference

# %%
from keras.datasets import mnist
from keras import backend as K


# input image dimensions
img_rows, img_cols = 28, 28

(_, _), (x_test, y_test) = mnist.load_data()

if K.image_data_format() == 'channels_first':
    x_test = x_test.reshape(x_test.shape[0], 1, img_rows, img_cols)
    input_shape = (1, img_rows, img_cols)
else:
    x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, 1)
    input_shape = (img_rows, img_cols, 1)

x_test = x_test.astype('float32')
x_test /= 255
print('x_test shape:', x_test.shape)
print(x_test.shape[0], 'test samples')
# Out:
# Using TensorFlow backend.
# x_test shape: (10000, 28, 28, 1)
# 10000 test samples

# %% [markdown]
# ### Make prediction

# %%
predictions = sess.run(softmax_tensor, {'import/conv2d_1_input:0': x_test[:20]})

# %%
[p.argmax() for p in predictions]
# Out:
# [7, 2, 1, 0, 4, 1, 4, 9, 5, 9, 0, 6, 9, 0, 1, 5, 9, 7, 3, 4]

# %%
y_test[:20]
# Out:
# array([7, 2, 1, 0, 4, 1, 4, 9, 5, 9, 0, 6, 9, 0, 1, 5, 9, 7, 3, 4],
#       dtype=uint8)

# %% [markdown]
# ### Loops through `NodeDef`s in `graph_def`
# Members of a `NodeDef`:
# * name
# * op
# * input
# * device
# * attr

# %%
for i, item in enumerate(graph_def.node):
    print(i, item.op, item.name, item.input)
# Out:
# 0 Placeholder conv2d_1_input []
# 1 Const conv2d_1/kernel []
# 2 Identity conv2d_1/kernel/read ['conv2d_1/kernel']
# 3 Const conv2d_1/bias []
# 4 Identity conv2d_1/bias/read ['conv2d_1/bias']
# 5 Conv2D conv2d_1/convolution ['conv2d_1_input', 'conv2d_1/kernel/read']
# 6 BiasAdd conv2d_1/BiasAdd ['conv2d_1/convolution', 'conv2d_1/bias/read']
# 7 Relu conv2d_1/Relu ['conv2d_1/BiasAdd']
# 8 Const conv2d_2/kernel []
# 9 Identity conv2d_2/kernel/read ['conv2d_2/kernel']
# 10 Const conv2d_2/bias []
# 11 Identity conv2d_2/bias/read ['conv2d_2/bias']
# 12 Conv2D conv2d_2/convolution ['conv2d_1/Relu', 'conv2d_2/kernel/read']
# 13 BiasAdd conv2d_2/BiasAdd ['conv2d_2/convolution', 'conv2d_2/bias/read']
# 14 Relu conv2d_2/Relu ['conv2d_2/BiasAdd']
# 15 MaxPool max_pooling2d_1/MaxPool ['conv2d_2/Relu']
# 16 Const dropout_1/keras_learning_phase/input []
# 17 PlaceholderWithDefault dropout_1/keras_learning_phase ['dropout_1/keras_learning_phase/input']
# 18 Switch dropout_1/cond/Switch ['dropout_1/keras_learning_phase', 'dropout_1/keras_learning_phase']
# 19 Identity dropout_1/cond/switch_t ['dropout_1/cond/Switch:1']
# 20 Identity dropout_1/cond/pred_id ['dropout_1/keras_learning_phase']
# 21 Const dropout_1/cond/mul/y ['^dropout_1/cond/switch_t']
# 22 Mul dropout_1/cond/mul ['dropout_1/cond/mul/Switch:1', 'dropout_1/cond/mul/y']
# 23 Switch dropout_1/cond/mul/Switch ['max_pooling2d_1/MaxPool', 'dropout_1/cond/pred_id']
# 24 Const dropout_1/cond/dropout/keep_prob ['^dropout_1/cond/switch_t']
# 25 Shape dropout_1/cond/dropout/Shape ['dropout_1/cond/mul']
# 26 Const dropout_1/cond/dropout/random_uniform/min ['^dropout_1/cond/switch_t']
# 27 Const dropout_1/cond/dropout/random_uniform/max ['^dropout_1/cond/switch_t']
# 28 RandomUniform dropout_1/cond/dropout/random_uniform/RandomUniform ['dropout_1/cond/dropout/Shape']
# 29 Sub dropout_1/cond/dropout/random_uniform/sub ['dropout_1/cond/dropout/random_uniform/max', 'dropout_1/cond/dropout/random_uniform/min']
# 30 Mul dropout_1/cond/dropout/random_uniform/mul ['dropout_1/cond/dropout/random_uniform/RandomUniform', 'dropout_1/cond/dropout/random_uniform/sub']
# 31 Add dropout_1/cond/dropout/random_uniform ['dropout_1/cond/dropout/random_uniform/mul', 'dropout_1/cond/dropout/random_uniform/min']
# 32 Add dropout_1/cond/dropout/add ['dropout_1/cond/dropout/keep_prob', 'dropout_1/cond/dropout/random_uniform']
# 33 Floor dropout_1/cond/dropout/Floor ['dropout_1/cond/dropout/add']
# 34 RealDiv dropout_1/cond/dropout/div ['dropout_1/cond/mul', 'dropout_1/cond/dropout/keep_prob']
# 35 Mul dropout_1/cond/dropout/mul ['dropout_1/cond/dropout/div', 'dropout_1/cond/dropout/Floor']
# 36 Switch dropout_1/cond/Switch_1 ['max_pooling2d_1/MaxPool', 'dropout_1/cond/pred_id']
# 37 Merge dropout_1/cond/Merge ['dropout_1/cond/Switch_1', 'dropout_1/cond/dropout/mul']
# 38 Shape flatten_1/Shape ['dropout_1/cond/Merge']
# 39 Const flatten_1/strided_slice/stack []
# 40 Const flatten_1/strided_slice/stack_1 []
# 41 Const flatten_1/strided_slice/stack_2 []
# 42 StridedSlice flatten_1/strided_slice ['flatten_1/Shape', 'flatten_1/strided_slice/stack', 'flatten_1/strided_slice/stack_1', 'flatten_1/strided_slice/stack_2']
# 43 Const flatten_1/Const []
# 44 Prod flatten_1/Prod ['flatten_1/strided_slice', 'flatten_1/Const']
# 45 Const flatten_1/stack/0 []
# 46 Pack flatten_1/stack ['flatten_1/stack/0', 'flatten_1/Prod']
# 47 Reshape flatten_1/Reshape ['dropout_1/cond/Merge', 'flatten_1/stack']
# 48 Const dense_1/kernel []
# 49 Identity dense_1/kernel/read ['dense_1/kernel']
# 50 Const dense_1/bias []
# 51 Identity dense_1/bias/read ['dense_1/bias']
# 52 MatMul dense_1/MatMul ['flatten_1/Reshape', 'dense_1/kernel/read']
# 53 BiasAdd dense_1/BiasAdd ['dense_1/MatMul', 'dense_1/bias/read']
# 54 Relu dense_1/Relu ['dense_1/BiasAdd']
# 55 Switch dropout_2/cond/Switch ['dropout_1/keras_learning_phase', 'dropout_1/keras_learning_phase']
# 56 Identity dropout_2/cond/switch_t ['dropout_2/cond/Switch:1']
# 57 Identity dropout_2/cond/pred_id ['dropout_1/keras_learning_phase']
# 58 Const dropout_2/cond/mul/y ['^dropout_2/cond/switch_t']
# 59 Mul dropout_2/cond/mul ['dropout_2/cond/mul/Switch:1', 'dropout_2/cond/mul/y']
# 60 Switch dropout_2/cond/mul/Switch ['dense_1/Relu', 'dropout_2/cond/pred_id']
# 61 Const dropout_2/cond/dropout/keep_prob ['^dropout_2/cond/switch_t']
# 62 Shape dropout_2/cond/dropout/Shape ['dropout_2/cond/mul']
# 63 Const dropout_2/cond/dropout/random_uniform/min ['^dropout_2/cond/switch_t']
# 64 Const dropout_2/cond/dropout/random_uniform/max ['^dropout_2/cond/switch_t']
# 65 RandomUniform dropout_2/cond/dropout/random_uniform/RandomUniform ['dropout_2/cond/dropout/Shape']
# 66 Sub dropout_2/cond/dropout/random_uniform/sub ['dropout_2/cond/dropout/random_uniform/max', 'dropout_2/cond/dropout/random_uniform/min']
# 67 Mul dropout_2/cond/dropout/random_uniform/mul ['dropout_2/cond/dropout/random_uniform/RandomUniform', 'dropout_2/cond/dropout/random_uniform/sub']
# 68 Add dropout_2/cond/dropout/random_uniform ['dropout_2/cond/dropout/random_uniform/mul', 'dropout_2/cond/dropout/random_uniform/min']
# 69 Add dropout_2/cond/dropout/add ['dropout_2/cond/dropout/keep_prob', 'dropout_2/cond/dropout/random_uniform']
# 70 Floor dropout_2/cond/dropout/Floor ['dropout_2/cond/dropout/add']
# 71 RealDiv dropout_2/cond/dropout/div ['dropout_2/cond/mul', 'dropout_2/cond/dropout/keep_prob']
# 72 Mul dropout_2/cond/dropout/mul ['dropout_2/cond/dropout/div', 'dropout_2/cond/dropout/Floor']
# 73 Switch dropout_2/cond/Switch_1 ['dense_1/Relu', 'dropout_2/cond/pred_id']
# 74 Merge dropout_2/cond/Merge ['dropout_2/cond/Switch_1', 'dropout_2/cond/dropout/mul']
# 75 Const dense_2/kernel []
# 76 Identity dense_2/kernel/read ['dense_2/kernel']
# 77 Const dense_2/bias []
# 78 Identity dense_2/bias/read ['dense_2/bias']
# 79 MatMul dense_2/MatMul ['dropout_2/cond/Merge', 'dense_2/kernel/read']
# 80 BiasAdd dense_2/BiasAdd ['dense_2/MatMul', 'dense_2/bias/read']
# 81 Softmax dense_2/Softmax ['dense_2/BiasAdd']
# 82 Const Adadelta/lr []
# 83 Const Adadelta/decay []
# 84 Const Adadelta/iterations []
# 85 Const training/Adadelta/Variable []
# 86 Const training/Adadelta/Variable_1 []
# 87 Const training/Adadelta/Variable_2 []
# 88 Const training/Adadelta/Variable_3 []
# 89 Const training/Adadelta/Variable_4 []
# 90 Const training/Adadelta/Variable_5 []
# 91 Const training/Adadelta/Variable_6 []
# 92 Const training/Adadelta/Variable_7 []
# 93 Const training/Adadelta/Variable_8 []
# 94 Const training/Adadelta/Variable_9 []
# 95 Const training/Adadelta/Variable_10 []
# 96 Const training/Adadelta/Variable_11 []
# 97 Const training/Adadelta/Variable_12 []
# 98 Const training/Adadelta/Variable_13 []
# 99 Const training/Adadelta/Variable_14 []
# 100 Const training/Adadelta/Variable_15 []

# %% [markdown]
# ### List of operations in the graph

# %%
for op in sess.graph.get_operations():
    print(op.name, op.type)
# Out:
# import/conv2d_1_input Placeholder
# import/conv2d_1/kernel Const
# import/conv2d_1/kernel/read Identity
# import/conv2d_1/bias Const
# import/conv2d_1/bias/read Identity
# import/conv2d_1/convolution Conv2D
# import/conv2d_1/BiasAdd BiasAdd
# import/conv2d_1/Relu Relu
# import/conv2d_2/kernel Const
# import/conv2d_2/kernel/read Identity
# import/conv2d_2/bias Const
# import/conv2d_2/bias/read Identity
# import/conv2d_2/convolution Conv2D
# import/conv2d_2/BiasAdd BiasAdd
# import/conv2d_2/Relu Relu
# import/max_pooling2d_1/MaxPool MaxPool
# import/dropout_1/keras_learning_phase/input Const
# import/dropout_1/keras_learning_phase PlaceholderWithDefault
# import/dropout_1/cond/Switch Switch
# import/dropout_1/cond/switch_t Identity
# import/dropout_1/cond/pred_id Identity
# import/dropout_1/cond/mul/y Const
# import/dropout_1/cond/mul/Switch Switch
# import/dropout_1/cond/mul Mul
# import/dropout_1/cond/dropout/keep_prob Const
# import/dropout_1/cond/dropout/Shape Shape
# import/dropout_1/cond/dropout/random_uniform/min Const
# import/dropout_1/cond/dropout/random_uniform/max Const
# import/dropout_1/cond/dropout/random_uniform/RandomUniform RandomUniform
# import/dropout_1/cond/dropout/random_uniform/sub Sub
# import/dropout_1/cond/dropout/random_uniform/mul Mul
# import/dropout_1/cond/dropout/random_uniform Add
# import/dropout_1/cond/dropout/add Add
# import/dropout_1/cond/dropout/Floor Floor
# import/dropout_1/cond/dropout/div RealDiv
# import/dropout_1/cond/dropout/mul Mul
# import/dropout_1/cond/Switch_1 Switch
# import/dropout_1/cond/Merge Merge
# import/flatten_1/Shape Shape
# import/flatten_1/strided_slice/stack Const
# import/flatten_1/strided_slice/stack_1 Const
# import/flatten_1/strided_slice/stack_2 Const
# import/flatten_1/strided_slice StridedSlice
# import/flatten_1/Const Const
# import/flatten_1/Prod Prod
# import/flatten_1/stack/0 Const
# import/flatten_1/stack Pack
# import/flatten_1/Reshape Reshape
# import/dense_1/kernel Const
# import/dense_1/kernel/read Identity
# import/dense_1/bias Const
# import/dense_1/bias/read Identity
# import/dense_1/MatMul MatMul
# import/dense_1/BiasAdd BiasAdd
# import/dense_1/Relu Relu
# import/dropout_2/cond/Switch Switch
# import/dropout_2/cond/switch_t Identity
# import/dropout_2/cond/pred_id Identity
# import/dropout_2/cond/mul/y Const
# import/dropout_2/cond/mul/Switch Switch
# import/dropout_2/cond/mul Mul
# import/dropout_2/cond/dropout/keep_prob Const
# import/dropout_2/cond/dropout/Shape Shape
# import/dropout_2/cond/dropout/random_uniform/min Const
# import/dropout_2/cond/dropout/random_uniform/max Const
# import/dropout_2/cond/dropout/random_uniform/RandomUniform RandomUniform
# import/dropout_2/cond/dropout/random_uniform/sub Sub
# import/dropout_2/cond/dropout/random_uniform/mul Mul
# import/dropout_2/cond/dropout/random_uniform Add
# import/dropout_2/cond/dropout/add Add
# import/dropout_2/cond/dropout/Floor Floor
# import/dropout_2/cond/dropout/div RealDiv
# import/dropout_2/cond/dropout/mul Mul
# import/dropout_2/cond/Switch_1 Switch
# import/dropout_2/cond/Merge Merge
# import/dense_2/kernel Const
# import/dense_2/kernel/read Identity
# import/dense_2/bias Const
# import/dense_2/bias/read Identity
# import/dense_2/MatMul MatMul
# import/dense_2/BiasAdd BiasAdd
# import/dense_2/Softmax Softmax
# import/Adadelta/lr Const
# import/Adadelta/decay Const
# import/Adadelta/iterations Const
# import/training/Adadelta/Variable Const
# import/training/Adadelta/Variable_1 Const
# import/training/Adadelta/Variable_2 Const
# import/training/Adadelta/Variable_3 Const
# import/training/Adadelta/Variable_4 Const
# import/training/Adadelta/Variable_5 Const
# import/training/Adadelta/Variable_6 Const
# import/training/Adadelta/Variable_7 Const
# import/training/Adadelta/Variable_8 Const
# import/training/Adadelta/Variable_9 Const
# import/training/Adadelta/Variable_10 Const
# import/training/Adadelta/Variable_11 Const
# import/training/Adadelta/Variable_12 Const
# import/training/Adadelta/Variable_13 Const
# import/training/Adadelta/Variable_14 Const
# import/training/Adadelta/Variable_15 Const

# %% [markdown]
# ## Visualize the `graph_def` in TensorBoard

# %%
from show_graph import show_graph

# %%
show_graph(tf.get_default_graph().as_graph_def())
# Out:
#         <iframe seamless style="width:1200px;height:620px;border:0" srcdoc="
#         <script>
#           function load() {
#             document.getElementById(&quot;graph0.5979390672039462&quot;).pbtxt = 'node {\n  name: &quot;import/conv2d_1_input&quot;\n  op: &quot;Placeholder&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n        dim {\n          size: -1\n        }\n        dim {\n          size: 28\n        }\n        dim {\n          size: 28\n        }\n        dim {\n          size: 1\n        }\n      }\n    }\n  }\n}\nnode {\n  name: &quot;import/conv2d_1/kernel&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_FLOAT\n        tensor_shape {\n          dim {\n            size: 3\n          }\n          dim {\n            size: 3\n          }\n          dim {\n            size: 1\n          }\n          dim {\n            size: 32\n          }\n        }\n        tensor_content: &quot;<stripped 1152 bytes>&quot;\n      }\n    }\n  }\n}\nnode {\n  name: &quot;import/conv2d_1/kernel/read&quot;\n  op: &quot;Identity&quot;\n  input: &quot;import/conv2d_1/kernel&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;_class&quot;\n    value {\n      list {\n        s: &quot;loc:@import/conv2d_1/kernel&quot;\n      }\n    }\n  }\n}\nnode {\n  name: &quot;import/conv2d_1/bias&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_FLOAT\n        tensor_shape {\n          dim {\n            size: 32\n          }\n        }\n        tensor_content: &quot;<stripped 128 bytes>&quot;\n      }\n    }\n  }\n}\nnode {\n  name: &quot;import/conv2d_1/bias/read&quot;\n  op: &quot;Identity&quot;\n  input: &quot;import/conv2d_1/bias&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;_class&quot;\n    value {\n      list {\n        s: &quot;loc:@import/conv2d_1/bias&quot;\n      }\n    }\n  }\n}\nnode {\n  name: &quot;import/conv2d_1/convolution&quot;\n  op: &quot;Conv2D&quot;\n  input: &quot;import/conv2d_1_input&quot;\n  input: &quot;import/conv2d_1/kernel/read&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;data_format&quot;\n    value {\n      s: &quot;NHWC&quot;\n    }\n  }\n  attr {\n    key: &quot;dilations&quot;\n    value {\n      list {\n        i: 1\n        i: 1\n        i: 1\n        i: 1\n      }\n    }\n  }\n  attr {\n    key: &quot;padding&quot;\n    value {\n      s: &quot;VALID&quot;\n    }\n  }\n  attr {\n    key: &quot;strides&quot;\n    value {\n      list {\n        i: 1\n        i: 1\n        i: 1\n        i: 1\n      }\n    }\n  }\n  attr {\n    key: &quot;use_cudnn_on_gpu&quot;\n    value {\n      b: true\n    }\n  }\n}\nnode {\n  name: &quot;import/conv2d_1/BiasAdd&quot;\n  op: &quot;BiasAdd&quot;\n  input: &quot;import/conv2d_1/convolution&quot;\n  input: &quot;import/conv2d_1/bias/read&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;data_format&quot;\n    value {\n      s: &quot;NHWC&quot;\n    }\n  }\n}\nnode {\n  name: &quot;import/conv2d_1/Relu&quot;\n  op: &quot;Relu&quot;\n  input: &quot;import/conv2d_1/BiasAdd&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n}\nnode {\n  name: &quot;import/conv2d_2/kernel&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_FLOAT\n        tensor_shape {\n          dim {\n            size: 3\n          }\n          dim {\n            size: 3\n          }\n          ...

# %%
# graph_def
show_graph(graph_def)
# Out:
#         <iframe seamless style="width:1200px;height:620px;border:0" srcdoc="
#         <script>
#           function load() {
#             document.getElementById(&quot;graph0.03003290109955714&quot;).pbtxt = 'node {\n  name: &quot;conv2d_1_input&quot;\n  op: &quot;Placeholder&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n        unknown_rank: true\n      }\n    }\n  }\n}\nnode {\n  name: &quot;conv2d_1/kernel&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_FLOAT\n        tensor_shape {\n          dim {\n            size: 3\n          }\n          dim {\n            size: 3\n          }\n          dim {\n            size: 1\n          }\n          dim {\n            size: 32\n          }\n        }\n        tensor_content: &quot;<stripped 1152 bytes>&quot;\n      }\n    }\n  }\n}\nnode {\n  name: &quot;conv2d_1/bias&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_FLOAT\n        tensor_shape {\n          dim {\n            size: 32\n          }\n        }\n        tensor_content: &quot;<stripped 128 bytes>&quot;\n      }\n    }\n  }\n}\nnode {\n  name: &quot;conv2d_1/convolution&quot;\n  op: &quot;Conv2D&quot;\n  input: &quot;conv2d_1_input&quot;\n  input: &quot;conv2d_1/kernel&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;data_format&quot;\n    value {\n      s: &quot;NHWC&quot;\n    }\n  }\n  attr {\n    key: &quot;dilations&quot;\n    value {\n      list {\n        i: 1\n        i: 1\n        i: 1\n        i: 1\n      }\n    }\n  }\n  attr {\n    key: &quot;padding&quot;\n    value {\n      s: &quot;VALID&quot;\n    }\n  }\n  attr {\n    key: &quot;strides&quot;\n    value {\n      list {\n        i: 1\n        i: 1\n        i: 1\n        i: 1\n      }\n    }\n  }\n  attr {\n    key: &quot;use_cudnn_on_gpu&quot;\n    value {\n      b: true\n    }\n  }\n}\nnode {\n  name: &quot;conv2d_1/BiasAdd&quot;\n  op: &quot;BiasAdd&quot;\n  input: &quot;conv2d_1/convolution&quot;\n  input: &quot;conv2d_1/bias&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;data_format&quot;\n    value {\n      s: &quot;NHWC&quot;\n    }\n  }\n}\nnode {\n  name: &quot;conv2d_1/Relu&quot;\n  op: &quot;Relu&quot;\n  input: &quot;conv2d_1/BiasAdd&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n}\nnode {\n  name: &quot;conv2d_2/kernel&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_FLOAT\n        tensor_shape {\n          dim {\n            size: 3\n          }\n          dim {\n            size: 3\n          }\n          dim {\n            size: 32\n          }\n          dim {\n            size: 64\n          }\n        }\n        tensor_content: &quot;<stripped 73728 bytes>&quot;\n      }\n    }\n  }\n}\nnode {\n  name: &quot;conv2d_2/bias&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_FLOAT\n        tensor_shape {\n          dim {\n            size: 64\n          }\n        }\n        tensor_content: &quot;<stripped 256 bytes>&quot;\n      }\n    }\n  }\n}\nnode {\n  name: &quot;conv2d_2/convolution&quot;\n  op: &quot;Conv2D&quot;\n  input: &quot;conv2d_1/Relu&quot;\n  input: &quot;conv2d_2/kernel&quot;\n  attr {\n    key: &quot;T&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;data_format&quot;\n    value {\n      s: &quot;NHWC&quot;\n    }\n  }\n  attr {\n    key ...
